# %% [markdown]
# <a href="https://colab.research.google.com/github/dnmalan/advanced-data-journalism-23/blob/main/0_Introduction_to_Binder_and_notebooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Day 1: Introduction to Binder and notebooks
#
# Python is a versatile programming language widely used in data analysis and visualization due to its rich ecosystem of libraries. Python itself has basic mathematical functions, and the Python community has built many hundreds of libraries that build upon this base and include functions for certain This course will focus on four crucial libraries: NumPy (math), Pandas (data analysis), Matplotlib, and Seaborn (visualization).
#
# First, let's get comfortable using a Jupyter notebook (via Binder to share the files) and learn some basic Python structure.

# %% [markdown]
# ![Screenshot 2023-09-03 at 9.46.08 AM.png](data:image/png;base64,...)

# %% [markdown]
# Binder is a platform that allows the instructor to set up a coding environment and share Jupyter notebooks. This is the url for all our course materials:
#
# https://mybinder.org/v2/gh/dnmalan/advanced-data-journalism-23/HEAD

# %% [markdown]
# All notebook files for class will be found in the course_materials folder on the left.
#
# <-------------------

# %% [markdown]
# ## Navigating the notebook
#
# Use the buttons at the top of the page to run code cells, add/delete cells, and save your notebook.
#
# ![Screenshot 2023-09-03 at 8.57.31 AM.png](data:image/png;base64,...)
#
#
# **Important:** If you want to save your work, download the notebook at the end of every class period.

# %% [markdown]
# ## Importing libraries
#
# The libraries we'll use for class are installed in this environment, and we'll need to add them to each notebook we use within that enviroment.
#
# Test it out by running this cell!
#
# Note: To run the cell, use either the **Play** button at the top of the notebook, or press **Shift + Return**.

# %%
# Import libraries (test - we will import these in every notebook)

import numpy as np
import pandas as pd
import matplotlib as plot
import seaborn as sb

# %% [markdown]
# ## Our first dataframe
#
# Now let's create our first dataframe in Pandas. We'll use a small dummy dataset of people's names and ages.

# %%
# Create a dataset of names and ages
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25, 30, 35]}

# %%
# Create a dataframe called "df" from that data
df = pd.DataFrame(data)

# %%
# View the dataframe
df

# %% [markdown]
# In notebooks, you can break code down into multiple cells, or put the code all together in one cell. For example, here is the same code above in one cell.
#
# Note: It is best practice to comment on your code using the # to make notation lines stating what that piece of code does.

# %%
# Create a dataset of names and ages
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25, 30, 35]}

# Create a dataframe called "df" from that data
df = pd.DataFrame(data)

# View the dataframe
df
